# %% [markdown]
# # 簡單結論
#
# ## python 基礎
#
# * 一半理論，一半實戰(有好用 lib 實戰)
#
# ## 電腦視覺
#
# * 多種大套件，包含圖片、影像、聲音，處理實戰
#
# ## 機器學習、深度學習 (理論)
#
# * ML
# * DL
#
# ## 機器學習、深度學習 (實戰)  (原 人體姿態偵測)
#
# * 筆電、電腦
# * 手機

# %% [markdown]
# # python lib
#
# * https://github.com/vinta/awesome-python
# * https://github.com/jobbole/awesome-python-cn

# %% [markdown]
# # python
#
# 一半一半，前半 python 基礎，後半 python lib 與實戰
#
#
# ## python 簡介
#
# * 語言簡介
# * 彩蛋
# * path 環境變量
#
# ## 基本資料型態與文字處理
#
# ### 類型
#
# * 類型轉換
#
# ### python 的資料結構
#
# * list
# * tuple
# * dictionary
# * set
#
# ### 文字處理
#
# * 字符集 Big5 utf8 unicode
# * 文字處理
# * 取代搜尋...
# * 正規表示式
#
#
# ## 基本的輸入與輸出
#
# * console
# * 寫入檔案
#
#
# ## python 邏輯運算
#
# * if else
# * while
# * for
# * range
# * break continue
#
#
# ## python 的函數 function map
#
# * function
# * map
# * 三元運算
# * local global
#
#
# ## class, module, 繼承
#
# ## 裝飾器
#
#
# ## pathlib
#
#
#
#
# ## 好用的 lib

# %% [markdown]
# # CV Computer Vision
#
# https://docs.opencv.org/4.x/d9/df8/tutorial_root.html
#
# ## 簡介電腦視覺 與 Opencv
#
# ## 圖片的操作
#
# * 圖片組成，RGB，顯示
# * 放大縮小， crop
# * 拼接
# * 寫字，畫圖
# * opencv 簡易 GUI
# * 圖片格式轉換 HSV
# * 圖片 形變
# * 圖片 特徵 corner
# * 圖片 edge det
# * 圖片 相似度
# * 圖片 品質 解析度 super reslution
# * opencv ROI
#
#
# ## 影片的操作
#
# * codec, 與容器的講解 (影片壓縮原理與格式H264, mpeg, ...)
# * moviepy
# * ffmpeg
# * opencv (細節錄影)
#
# ## 聲音的操作
#
# * moviepy
# * ffmpeg
#
#
# ## scikit-image and Pillow
#
# * https://scikit-image.org/
# * https://pillow.readthedocs.io/en/stable/handbook/tutorial.html
#
#
# ## data-augmentation
#
# * tf, keras, pytorch
# * https://neptune.ai/blog/data-augmentation-in-python
# * https://github.com/CrazyVertigo/awesome-data-augmentation
# * https://www.analyticsvidhya.com/blog/2022/04/image-augmentation-using-3-python-libraries/

# %% [markdown]
# # 機器學習
#
# scikit-learn
# 我的講義
#
#
# # 深度學習
#
# * [d2l](https://zh.d2l.ai/chapter_preliminaries/index.html)
#
#
# ## Linear Neural Networks for Regression
#
# ## Linear Neural Networks for Classification

# %% [markdown]
# # 姿態辨識與其他應用的手機實戰
#
# 理論可用
# * https://learnopencv.com/deep-learning-based-human-pose-estimation-using-opencv-cpp-python/
# * https://www.analyticsvidhya.com/blog/2022/01/a-comprehensive-guide-on-human-pose-estimation/
#
#
# ## yolov7
#
# * https://github.com/WongKinYiu/yolov7
#
# ## detectron2
#
# * https://github.com/facebookresearch/detectron2
#
# ## MediaPipe
#
# * https://google.github.io/mediapipe/solutions/pose.html
#
# ## tflite
#
# * https://www.tensorflow.org/lite/examples/pose_estimation/overview
#
# * [圖片分類](https://codelabs.developers.google.com/codelabs/recognize-flowers-with-tensorflow-on-android/#0)
#
# *
